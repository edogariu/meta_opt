# %% [markdown]
# # TODOS
# - [X] shard!
# - [X] make sure we instantiate the big arrays in sharded form from the init fn!
# - [X] make sure we pad flattened params/grads to divide `n_opt_devices`
# - [X] add `bfloat16` support cause memory matters

# %%
# assert 'batch' in MESH.axis_names

from meta_opt.optimizers.base import OptimizerConfig
from meta_opt.optimizers.sgd import SGDConfig
from meta_opt.optimizers.adamw import AdamWConfig
from meta_opt.optimizers.metaopt import MetaOptConfig

import tqdm
import functools
import os
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count=8'

import jax
import jax.numpy as jnp
from jax.sharding import NamedSharding, Mesh, PartitionSpec as P
from jax.experimental import mesh_utils
from jax.experimental.shard_map import shard_map
from flax import jax_utils, struct
import optax

# %%
# %%capture
# !pip3 install memory-profiler
# %load_ext memory_profiler
# !pip3 install tensorflow tensorboard-plugin-profile
# !pip3 install ml-dtypes==0.2.0

# %%
# import os
# if os.path.isdir('/tmp/trace'):
#     import shutil
#     shutil.rmtree("/tmp/trace")

# @functools.partial(jax.pmap, axis_name='batch', in_axes=(0, 0, 0, None), out_axes=(0, 0), static_broadcasted_argnums=(3,)) 
# def _pmapped_train_step(batch, params, opt_state, opt):
#     loss_fn = LossFn(batch)
#     grads = jax.grad(loss_fn)(params)
#     grads = jax.lax.pmean(grads, axis_name='batch')

#     # dh = jax.lax.with_sharding_constraint(opt_state[0].disturbance_history, NamedSharding(MESH, P(None, 'opt')))
#     # ph = jax.lax.with_sharding_constraint(opt_state[0].param_history, NamedSharding(MESH, P(None, 'opt')))
#     # opt_state = (opt_state[0].replace(disturbance_history=dh, param_history=ph), opt_state[1])
    
#     updates, opt_state = opt[1](grads, opt_state, params, cost_fn=loss_fn)

#     # dh = jax.lax.with_sharding_constraint(opt_state[0].disturbance_history, NamedSharding(MESH, P(None, 'opt')))
#     # ph = jax.lax.with_sharding_constraint(opt_state[0].param_history, NamedSharding(MESH, P(None, 'opt')))
#     # opt_state = (opt_state[0].replace(disturbance_history=dh, param_history=ph), opt_state[1])
    
#     params = optax.apply_updates(params, updates)
#     return params, opt_state

# def pmapped_train_step(batch, replicated_params, replicated_opt_state, opt):
#     batch = batch.reshape(BATCH_NUM_DEVICES, -1, NUM_DATA)
#     sharded_batch = jax.device_put(batch, NamedSharding(MESH, P('batch', None, None)))
    
#     # print(replicated_opt_state[0].disturbance_history.sharding, replicated_opt_state[0].disturbance_history.shape)
#     replicated_params, replicated_opt_state = _pmapped_train_step(sharded_batch, replicated_params, replicated_opt_state, opt)
#     # print(replicated_opt_state[0].disturbance_history.sharding, replicated_opt_state[0].disturbance_history.shape)
    
#     return replicated_params, replicated_opt_state

# # with jax.profiler.trace('/tmp/trace'):

# opt = cfg.make_jax()
# opt = (jax.tree_util.Partial(opt.init), jax.tree_util.Partial(opt.update))
# params = make_params(0)  # make some pretend parameters
# opt_state = make_opt_state(params, opt)

# # replicate
# replicate_fn = lambda v: jnp.tile(v[None], (BATCH_NUM_DEVICES,) + ((1,) * v.ndim))
# unreplicate_fn = lambda v: v[0]

# replicated_params = replicate_fn(params)
# replicated_params = jax.device_put(replicated_params, NamedSharding(MESH, P('batch')))

# # replicated_opt_state = opt_state
# replicated_opt_state = jax.tree_map(replicate_fn, opt_state)

# replicated_opt_state = shard_opt_state(replicated_opt_state)  # uncomment this line to shard the optimizer state
# jax.debug.visualize_array_sharding(unreplicate_fn(replicated_opt_state[0].disturbance_history))

# # do a few steps of pmapped GD
# for seed in tqdm.trange(90):
#     batch = make_batch(seed)
#     replicated_params, replicated_opt_state = pmapped_train_step(batch, replicated_params, replicated_opt_state, opt)

# jax.debug.visualize_array_sharding(unreplicate_fn(replicated_opt_state[0].disturbance_history))
# %timeit pmapped_train_step(batch, replicated_params, replicated_opt_state, opt)[0].block_until_ready()

# # %load_ext tensorboard
# # %tensorboard --logdir=/tmp/trace

# %%
# import os
# if os.path.isdir('/tmp/trace'):
#     import shutil
#     shutil.rmtree("/tmp/trace")

# from jax.experimental.shard_map import shard_map

# replicate_fn = lambda v: jnp.tile(v, (BATCH_NUM_DEVICES,) + ((1,) * (v.ndim - 1))) if v.ndim > 0 else v
# unreplicate_fn = lambda v: v[:(v.shape[0] // BATCH_NUM_DEVICES)] if v.ndim > 0 else v

# def make_shardings(opt, spec):
#     shardings = {
#         # to replicate
#         'gpc_params': P(),
#         # 'gpc_tx': P(),
#         'gpc_opt_state': P(),
#         # 'H': P(),
#         # 'HH': P(),
#         't': P(),
#         # 'num_params': P(),
#         # 'base_lr': P(),
#         # 'disturbance_transform': P(),
#         'disturbance_transform_state': P(),
#         'recent_gpc_grads': P(),
#         'recent_gpc_cost': P(),
#         'cost_fn_history': P(),
    
#         # to shard along num_params axis
#         'disturbance_history': spec,
#         'param_history': spec,
#     }
#     os = make_opt_state(make_params(0), opt)
#     shardings = (os[0].replace(**shardings), optax.EmptyState())
#     del os
#     return shardings

# opt = cfg.make_jax()
# opt = (jax.tree_util.Partial(opt.init), jax.tree_util.Partial(opt.update))
# shardings = make_shardings(opt, P('batch', None))
# s2 = jax.tree_map(lambda v: NamedSharding(MESH, v), make_shardings(opt, P('batch', 'opt')))

# @functools.partial(shard_map, mesh=MESH, in_specs=(P('batch'), P('batch'), shardings, P()), out_specs=(P('batch'), shardings), check_rep=False)
# def _shmapped_train_step(batch, params, opt_state, opt):
#     loss_fn = LossFn(batch)
#     grads = jax.grad(loss_fn)(params)
#     grads = jax.lax.pmean(grads, axis_name='batch')
#     updates, opt_state = opt[1](grads, opt_state, params, cost_fn=loss_fn)
#     params = optax.apply_updates(params, updates)
#     return params, opt_state

# @jax.jit
# def shmapped_train_step(batch, params, opt_state, opt):
#     # assert params.ndim == 2 and batch.ndim == 2 and opt_state[0].disturbance_history.ndim == 3, (params.shape, batch.shape, opt_state[0].disturbance_history.shape)
#     # print(opt_state[0].disturbance_history.shape, opt_state[0].disturbance_history.sharding)
#     batch = jax.device_put(batch, NamedSharding(MESH, P('batch', None)))
#     opt_state = jax.lax.with_sharding_constraint(opt_state, s2)
#     params, opt_state = _shmapped_train_step(batch, params, opt_state, opt)
#     opt_state = jax.lax.with_sharding_constraint(opt_state, s2)
#     # print(opt_state[0].disturbance_history.shape, opt_state[0].disturbance_history.sharding)
#     return params, opt_state

# with jax.profiler.trace('/tmp/trace'):

#     # opt = cfg.make_jax()
#     # opt = (jax.tree_util.Partial(opt.init), jax.tree_util.Partial(opt.update))
#     params = make_params(0)  # make some pretend parameters
#     opt_state = make_opt_state(params, opt)
    
#     # replicate
#     replicated_params = jax.device_put(replicate_fn(params), NamedSharding(MESH, P('batch')))
#     replicated_opt_state = (opt_state[0].replace(disturbance_history=replicate_fn(opt_state[0].disturbance_history), 
#                                                  param_history=replicate_fn(opt_state[0].param_history)), opt_state[1])
#     replicated_opt_state = shard_opt_state(replicated_opt_state)  # uncomment this line to shard the optimizer state
#     print(replicated_opt_state[0].disturbance_history.shape, replicated_opt_state[0].disturbance_history.sharding)
    
#     # do a few steps of pmapped GD
#     for seed in tqdm.trange(74):
#         batch = make_batch(seed)
#         replicated_params, replicated_opt_state = shmapped_train_step(batch, replicated_params, replicated_opt_state, opt)
    
# %load_ext tensorboard
# %tensorboard --logdir=/tmp/trace

# %%
# import os
# if os.path.isdir('/tmp/trace'):
#     import shutil
#     shutil.rmtree("/tmp/trace")

# @jax.jit
# def sharded_train_step(batch, params, opt_state, opt):
#     loss_fn = LossFn(batch)
#     grads = jax.grad(loss_fn)(params)
#     updates, opt_state = opt[1](grads, opt_state, params, cost_fn=loss_fn)
#     params = optax.apply_updates(params, updates)
#     return params, opt_state

# with jax.profiler.trace('/tmp/trace'):

#     opt = cfg.make_jax()
#     opt = (jax.tree_util.Partial(opt.init), jax.tree_util.Partial(opt.update))
#     params = make_params(0)  # make some pretend parameters
#     opt_state = make_opt_state(params, opt)
    
#     opt_state = shard_opt_state(opt_state)  # uncomment this line to shard the optimizer state
    
#     # do a few steps of pmapped GD
#     for seed in tqdm.trange(90):
#         batch = make_batch(seed)
#         batch = jax.device_put(batch, NamedSharding(MESH, P('batch', None)))
#         params, opt_state = sharded_train_step(batch, params, opt_state, opt)
#     %timeit sharded_train_step(batch, params, opt_state, opt)[0].block_until_ready()

# %load_ext tensorboard
# %tensorboard --logdir=/tmp/trace

# %% [markdown]
# # Profile a full run

# %%
import os
if os.path.isdir('/tmp/trace'):
    import shutil
    shutil.rmtree("/tmp/trace")

import sys
from absl import logging, flags
from meta_opt.algoperf.runner import run
from meta_opt.experiment import ExperimentConfig
from meta_opt.utils import make_mesh, GLOBAL_MESH

logging.set_verbosity(logging.INFO)
flags.FLAGS(['runner.py', '--config_path=hi'])

experiment_cfg = ExperimentConfig(
    experiment_name='test',
    
    # workload details
    seed=0,
    workload_name='mnist', 
    full_batch=False,  # whether to do full gradient descent on one batch (fixed during the whole training) or regular minibatch SGD
    num_episodes=1,
    num_iters=200,  # if None, uses default for the workload

    framework='jax',
    num_batch_devices=1,
    num_opt_devices=8,

    # how often to do things
    eval_every=-1,
    checkpoint_every=-1,
    log_every=5,

    # other details
    use_wandb=False,
    print_with_colors=True)

# optimizer_cfg = AdamWConfig(learning_rate=0.001, b1=0.9, b2=0.999, eps=1e-8, weight_decay=None, grad_clip=None)
optimizer_cfg = MetaOptConfig(initial_learning_rate=0.1, weight_decay=1e-4, grad_clip=None,
                            H=64, HH=2, m_method='scalar', scale_by_adam_betas=None,
                            use_bfloat16=False,
                            fake_the_dynamics=False, freeze_gpc_params=False, freeze_cost_fn_during_rollouts=False,
                            meta_optimizer_cfg=SGDConfig(learning_rate=1e-5, momentum=0, nesterov=False, weight_decay=None, grad_clip=None))

with jax.profiler.trace('/tmp/trace'):
    make_mesh(experiment_cfg.num_batch_devices, experiment_cfg.num_opt_devices)
    run(experiment_cfg, optimizer_cfg)

# %load_ext tensorboard
# %tensorboard --logdir=/tmp/trace
# Out:
# INFO:absl: 8 devices in a mesh Mesh(device_ids=array([[0, 1, 2, 3, 4, 5, 6, 7]]), axis_names=('batch', 'opt')) of shape OrderedDict([('batch', 1), ('opt', 8)])
# INFO:absl:Creating directory at /Users/evandogariu/Desktop/meta-opt/experiments/test/mnist_jax for experiments to be saved to.
# INFO:absl:no `batch_size` provided. using default of 512 for the workload mnist!
# INFO:absl: 8 devices in a mesh Mesh(device_ids=array([[0, 1, 2, 3, 4, 5, 6, 7]]), axis_names=('batch', 'opt')) of shape OrderedDict([('batch', 1), ('opt', 8)])
# INFO:absl:Using cpu for jax
# INFO:absl:==========================================================================
# INFO:absl:EXPERIMENT CONFIG
# INFO:absl:==========================================================================
# INFO:absl:{ 'experiment_name': 'test',
#   'seed': 0,
#   'workload_name': 'mnist',
#   'full_batch': False,
#   'num_episodes': 1,
#   'num_iters': 200,
#   'batch_size': 512,
#   'framework': 'jax',
#   'num_batch_devices': 1,
#   'num_opt_devices': 8,
#   'eval_every': -1,
#   'checkpoint_every': -1,
#   'log_every': 5,
#   'print_with_colors': True,
#   'use_wandb': False}
# INFO:absl:
#
# INFO:absl:==========================================================================
# INFO:absl:OPTIMIZER CONFIG
# INFO:absl:==========================================================================
# INFO:absl:{ 'initial_learning_rate': 0.1,
#   'weight_decay': 0.0001,
#   'grad_clip': None,
#   'scale_by_adam_betas': None,
#   'H': 64,
#   'HH': 2,
#   'm_method': 'scalar',
#   'meta_optimizer_cfg': { 'learning_rate': 1e-05,
#                           'momentum': 0,
#                           'nesterov': False,
#                           'weight_decay': None,
#                           'grad_clip': None,
#                           'optimizer_name': 'SGD',
#                           'self_tuning': False,
#                           'reset_opt_state': True},
#   'fake_the_dynamics': False,
#   'freeze_gpc_params': False,
#   'freeze_cost_fn_during_rollouts': False,
#   'use_bfloat16': False,
#   'optimizer_name': 'MetaOpt',
#   'self_tuning': True,
#   'reset_opt_state': True}
# INFO:absl:
#
#
# INFO:absl:
# INFO:absl:experiment_dir=/Users/evandogariu/Desktop/meta-opt/experiments/test/mnist_jax
# INFO:absl:seed=0
# INFO:absl:Initializing dataset for workload: mnist.
# INFO:absl:Load dataset info from /Users/evandogariu/Desktop/meta-opt/datasets/mnist/3.0.1
# INFO:absl:For 'mnist/3.0.1': fields info.[citation, splits, supervised_keys, module_name] differ on disk and in the code. Keeping the one from code.
# INFO:absl:Reusing dataset mnist (/Users/evandogariu/Desktop/meta-opt/datasets/mnist/3.0.1)
# INFO:absl:Constructing tf.data.Dataset mnist for split train[:50000], from /Users/evandogariu/Desktop/meta-opt/datasets/mnist/3.0.1
# INFO:absl:Initializing the model (for mnist) and also optimizer: MetaOpt
# INFO:absl:sharding opt state across 8 devices
# INFO:absl:needed to pad iterates from 101770 to 101776 to evenly divide over 8 devices
# INFO:absl:Model has 814160 parameters and the optimizer state takes 0.01MB
# INFO:absl:Initializing checkpoint and metrics.
# INFO:absl:Found no checkpoint files in /Users/evandogariu/Desktop/meta-opt/experiments/test/mnist_jax with prefix checkpoint_
# INFO:absl:Saving meta data to /Users/evandogariu/Desktop/meta-opt/experiments/test/mnist_jax/meta_data_0.json.
# INFO:absl:Saving config to /Users/evandogariu/Desktop/meta-opt/experiments/test/mnist_jax/config_0.json.
# WARNING:absl:I found no checkpoint, so we proceed without loading :)
# INFO:absl:Starting training loop.
# INFO:absl:Resetting model!
# INFO:absl:Also resetting optimizer state!
# INFO:absl:[1] M_0=-0.10000000149011612, M_1=0.0, M_10=0.0, M_11=0.0, M_12=0.0, M_13=0.0, M_14=0.0, M_15=0.0, M_16=0.0, M_17=0.0, M_18=0.0, M_19=0.0, M_2=0.0, M_20=0.0, M_21=0.0, M_22=0.0, M_23=0.0, M_24=0.0, M_25=0.0, M_26=0.0, M_27=0.0, M_28=0.0, M_29=0.0, M_3=0.0, M_30=0.0, M_31=0.0, M_32=0.0, M_33=0.0, M_34=0.0, M_35=0.0, M_36=0.0, M_37=0.0, M_38=0.0, M_39=0.0, M_4=0.0, M_40=0.0, M_41=0.0, M_42=0.0, M_43=0.0, M_44=0.0, M_45=0.0, M_46=0.0, M_47=0.0, M_48=0.0, M_49=0.0, M_5=0.0, M_50=0.0, M_51=0.0, M_52=0.0, M_53=0.0, M_54=0.0, M_55=0.0, M_56=0.0, M_57=0.0, M_58=0.0, M_59=0.0, M_6=0.0, M_60=0.0, M_61=0.0, M_62=0.0, M_63=0.0, M_7=0.0, M_8=0.0, M_9=0.0, cost_fn_history_memory=19699, cpu.freq.current=3504, cpu.util.avg_percent_since_last=31.900000, disturbance_history_memory=640, disturbance_transform_state_memory=40, global_step=1, grad_sq_norm=44.306305, loss=2.645919, mem.available=12246401024, mem.percent_used=52.500000, mem.read_bytes_since_boot=250886074368, mem.total=25769803776, mem.used=12315607040, mem.write_bytes_since_boot=286689656832, model_state_memory=16, net.bytes_recv_since_boot=3618305024, net.bytes_sent_since_boot=1552443392, opt_state_memory=27085, param_history_memory=640, param_memory=160, param_sq_norm=137.5640106201172, step_time=0.561560, total_metaopt_memory=26989
# INFO:absl:[5] M_0=-0.10000000149011612, M_1=0.0, M_10=0.0, M_11=0.0, M_12=0.0, M_13=0.0, M_14=0.0, M_15=0.0, M_16=0.0, M_17=0.0, M_18=0.0, M_19=0.0, M_2=0.0, M_20=0.0, M_21=0.0, M_22=0.0, M_23=0.0, M_24=0.0, M_25=0.0, M_26=0.0, M_27=0.0, M_28=0.0, M_29=0.0, M_3=0.0, M_30=0.0, M_31=0.0, M_32=0.0, M_33=0.0, M_34=0.0, M_35=0.0, M_36=0.0, M_37=0.0, M_38=0.0, M_39=0.0, M_4=0.0, M_40=0.0, M_41=0.0, M_42=0.0, M_43=0.0, M_44=0.0, M_45=0.0, M_46=0.0, M_47=0.0, M_48=0.0, M_49=0.0, M_5=0.0, M_50=0.0, M_51=0.0, M_52=0.0, M_53=0.0, M_54=0.0, M_55=0.0, M_56=0.0, M_57=0.0, M_58=0.0, M_59=0.0, M_6=0.0, M_60=0.0, M_61=0.0, M_62=0.0, M_63=0.0, M_7=0.0, M_8=0.0, M_9=0.0, cost_fn_history_memory=21819, cpu.freq.current=3504, cpu.util.avg_percent_since_last=33.600000, disturbance_history_memory=640, disturbance_transform_state_memory=40, global_step=5, grad_sq_norm=17.595272, loss=1.870283, mem.available=12266455040, mem.percent_used=52.400000, mem.read_bytes_since_boot=250886074368, mem.total=25769803776, mem.used=12295143424, mem.write_bytes_since_boot=286690275328, model_state_memory=16, net.bytes_recv_since_boot=3618341888, net.bytes_sent_since_boot=1552480256, opt_state_memory=29205, param_history_memory=640, param_memory=160, param_sq_norm=138.33493041992188, step_time=0.036223, total_metaopt_memory=29109
# INFO:absl:[10] M_0=-0.10000000149011612, M_1=0.0, M_10=0.0, M_11=0.0, M_12=0.0, M_13=0.0, M_14=0.0, M_15=0.0, M_16=0.0, M_17=0.0, M_18=0.0, M_19=0.0, M_2=0.0, M_20=0.0, M_21=0.0, M_22=0.0, M_23=0.0, M_24=0.0, M_25=0.0, M_26=0.0, M_27=0.0, M_28=0.0, M_29=0.0, M_3=0.0, M_30=0.0, M_31=0.0, M_32=0.0, M_33=0.0, M_34=0.0, M_35=0.0, M_36=0.0, M_37=0.0, M_38=0.0, M_39=0.0, M_4=0.0, M_40=0.0, M_41=0.0, M_42=0.0, M_43=0.0, M_44=0.0, M_45=0.0, M_46=0.0, M_47=0.0, M_48=0.0, M_49=0.0, M_5=0.0, M_50=0.0, M_51=0.0, M_52=0.0, M_53=0.0, M_54=0.0, M_55=0.0, M_56=0.0, M_57=0.0, M_58=0.0, M_59=0.0, M_6=0.0, M_60=0.0, M_61=0.0, M_62=0.0, M_63=0.0, M_7=0.0, M_8=0.0, M_9=0.0, cost_fn_history_memory=21819, cpu.freq.current=3504, cpu.util.avg_percent_since_last=62.900000, disturbance_history_memory=640, disturbance_transform_state_memory=40, global_step=10, grad_sq_norm=10.524629, loss=1.598665, mem.available=12232572928, mem.percent_used=52.500000, mem.read_bytes_since_boot=250886074368, mem.total=25769803776, mem.used=12330270720, mem.write_bytes_since_boot=286690283520, model_state_memory=16, net.bytes_recv_since_boot=3618350080, net.bytes_sent_since_boot=1552496640, opt_state_memory=29205, param_history_memory=640, param_memory=160, param_sq_norm=139.3906707763672, step_time=0.040752, total_metaopt_memory=29109
# INFO:absl:[15] M_0=-0.10000000149011612, M_1=0.0, M_10=0.0, M_11=0.0, M_12=0.0, M_13=0.0, M_14=0.0, M_15=0.0, M_16=0.0, M_17=0.0, M_18=0.0, M_19=0.0, M_2=0.0, M_20=0.0, M_21=0.0, M_22=0.0, M_23=0.0, M_24=0.0, M_25=0.0, M_26=0.0, M_27=0.0, M_28=0.0, M_29=0.0, M_3=0.0, M_30=0.0, M_31=0.0, M_32=0.0, M_33=0.0, M_34=0.0, M_35=0.0, M_36=0.0, M_37=0.0, M_38=0.0, M_39=0.0, M_4=0.0, M_40=0.0, M_41=0.0, M_42=0.0, M_43=0.0, M_44=0.0, M_45=0.0, M_46=0.0, M_47=0.0, M_48=0.0, M_49=0.0, M_5=0.0, M_50=0.0, M_51=0.0, M_52=0.0, M_53=0.0, M_54=0.0, M_55=0.0, M_56=0.0, M_57=0.0, M_58=0.0, M_59=0.0, M_6=0.0, M_60=0.0, M_61=0.0, M_62=0.0, M_63=0.0, M_7=0.0, M_8=0.0, M_9=0.0, cost_fn_history_memory=21819, cpu.freq.current=3504, cpu.util.avg_percent_since_last=56.100000, disturbance_history_memory=640, disturbance_transform_state_memory=40, global_step=15, grad_sq_norm=10.290500, loss=1.392488, mem.available=12216188928, mem.percent_used=52.600000, mem.read_bytes_since_boot=250886074368, mem.total=25769803776, mem.used=12345606144, mem.write_bytes_since_boot=286690902016, model_state_memory=16, net.bytes_recv_since_boot=3618417664, net.bytes_sent_since_boot=1552556032, opt_state_memory=29205, param_history_memory=640, param_memory=160, param_sq_norm=140.3802032470703, step_time=0.034254, total_metaopt_memory=29109
# INFO:absl:[20] M_0=-0.10000000149011612, M_1=0.0, M_10=0.0, M_11=0.0, M_12=0.0, M_13=0.0, M_14=0.0, M_15=0.0, M_16=0.0, M_17=0.0, M_18=0.0, M_19=0.0, M_2=0.0, M_20=0.0, M_21=0.0, M_22=0.0, M_23=0.0, M_24=0.0, M_25=0.0, M_26=0.0, M_27=0.0, M_28=0.0, M_29=0.0, M_3=0.0, M_30=0.0, M_31=0.0, M_32=0.0, M_33=0.0, M_34=0.0, M_35=0.0, M_36=0.0, M_37=0.0, M_38=0.0, M_39=0.0, M_4=0.0, M_40=0.0, M_41=0.0, M_42=0.0, M_43=0.0, M_44=0.0, M_45=0.0, M_46=0.0, M_47=0.0, M_48=0.0, M_49=0.0, M_5=0.0, M_50=0.0, M_51=0.0, M_52=0.0, M_53=0.0, M_54=0.0, M_55=0.0, M_56=0.0, M_57=0.0, M_58=0.0, M_59=0.0, M_6=0.0, M_60=0.0, M_61=0.0, M_62=0.0, M_63=0.0, M_7=0.0, M_8=0.0, M_9=0.0, cost_fn_history_memory=21819, cpu.freq.current=3504, cpu.util.avg_percent_since_last=56.900000, disturbance_history_memory=640, disturbance_transform_state_memory=40, global_step=20, grad_sq_norm=10.671506, loss=1.259626, mem.available=12232179712, mem.percent_used=52.500000, mem.read_bytes_since_boot=250886074368, mem.total=25769803776, mem.used=12330074112, mem.write_bytes_since_boot=286690906112, model_state_memory=16, net.bytes_recv_since_boot=3618426880, net.bytes_sent_since_boot=1552564224, opt_state_memory=29205, param_history_memory=640, param_memory=160, param_sq_norm=141.47915649414062, step_time=0.038633, total_metaopt_memory=29109
# INFO:absl:[25] M_0=-0.10000000149011612, M_1=0.0, M_10=0.0, M_11=0.0, M_12=0.0, M_13=0.0, M_14=0.0, M_15=0.0, M_16=0.0, M_17=0.0, M_18=0.0, M_19=0.0, M_2=0.0, M_20=0.0, M_21=0.0, M_22=0.0, M_23=0.0, M_24=0.0, M_25=0.0, M_26=0.0, M_27=0.0, M_28=0.0, M_29=0.0, M_3=0.0, M_30=0.0, M_31=0.0, M_32=0.0, M_33=0.0, M_34=0.0, M_35=0.0, M_36=0.0, M_37=0.0, M_38=0.0, M_39=0.0, M_4=0.0, M_40=0.0, M_41=0.0, M_42=0.0, M_43=0.0, M_44=0.0, M_45=0.0, M_46=0.0, M_47=0.0, M_48=0.0, M_49=0.0, M_5=0.0, M_50=0.0, M_51=0.0, M_52=0.0, M_53=0.0, M_54=0.0, M_55=0.0, M_56=0.0, M_57=0.0, M_58=0.0, M_59=0.0, M_6=0.0, M_60=0.0, M_61=0.0, M_62=0.0, M_63=0.0, M_7=0.0, M_8=0.0, M_9=0.0, cost_fn_history_memory=21819, cpu.freq.current=3504, cpu.util.avg_percent_since_last=59.600000, disturbance_history_memory=640, disturbance_transform_state_memory=40, global_step=25, grad_sq_norm=7.020358, loss=1.131743, mem.available=12227248128, mem.percent_used=52.600000, mem.read_bytes_since_boot=250886074368, mem.total=25769803776, mem.used=12335153152, mem.write_bytes_since_boot=286690910208, model_state_memory=16, net.bytes_recv_since_boot=3618435072, net.bytes_sent_since_boot=1552572416, opt_state_memory=29205, param_history_memory=640, param_memory=160, param_sq_norm=142.5486297607422, step_time=0.036306, total_metaopt_memory=29109
# INFO:absl:[30] M_0=-0.10000000149011612, M_1=0.0, M_10=0.0, M_11=0.0, M_12=0.0, M_13=0.0, M_14=0.0, M_15=0.0, M_16=0.0, M_17=0.0, M_18=0.0, M_19=0.0, M_2=0.0, M_20=0.0, M_21=0.0, M_22=0.0, M_23=0.0, M_24=0.0, M_25=0.0, M_26=0.0, M_27=0.0, M_28=0.0, M_29=0.0, M_3=0.0, M_30=0.0, M_31=0.0, M_32=0.0, M_33=0.0, M_34=0.0, M_35=0.0, M_36=0.0, M_37=0.0, M_38=0.0, M_39=0.0, M_4=0.0, M_40=0.0, M_41=0.0, M_42=0.0, M_43=0.0, M_44=0.0, M_45=0.0, M_46=0.0, M_47=0.0, M_48=0.0, M_49=0.0, M_5=0.0, M_50=0.0, M_51=0.0, M_52=0.0, M_53=0.0, M_54=0.0, M_55=0.0, M_56=0.0, M_57=0.0, M_58=0.0, M_59=0.0, M_6=0.0, M_60=0.0, M_61=0.0, M_62=0.0, M_63=0.0, M_7=0.0, M_8=0.0, M_9=0.0, cost_fn_history_memory=21819, cpu.freq.current=3504, cpu.util.avg_percent_since_last=56.700000, disturbance_history_memory=640, disturbance_transform_state_memory=40, global_step=30, grad_sq_norm=9.066643, loss=0.984820, mem.available=12225134592, mem.percent_used=52.600000, mem.read_bytes_since_boot=250886074368, mem.total=25769803776, mem.used=12338757632, mem.write_bytes_since_boot=286690914304, model_state_memory=16, net.bytes_recv_since_boot=3618444288, net.bytes_sent_since_boot=1552581632, opt_state_memory=29205, param_history_memory=640, param_memory=160, param_sq_norm=143.65283203125, step_time=0.036148, total_metaopt_memory=29109
# INFO:absl:[35] M_0=-0.10000000149011612, M_1=0.0, M_10=0.0, M_11=0.0, M_12=0.0, M_13=0.0, M_14=0.0, M_15=0.0, M_16=0.0, M_17=0.0, M_18=0.0, M_19=0.0, M_2=0.0, M_20=0.0, M_21=0.0, M_22=0.0, M_23=0.0, M_24=0.0, M_25=0.0, M_26=0.0, M_27=0.0, M_28=0.0, M_29=0.0, M_3=0.0, M_30=0.0, M_31=0.0, M_32=0.0, M_33=0.0, M_34=0.0, M_35=0.0, M_36=0.0, M_37=0.0, M_38=0.0, M_39=0.0, M_4=0.0, M_40=0.0, M_41=0.0, M_42=0.0, M_43=0.0, M_44=0.0, M_45=0.0, M_46=0.0, M_47=0.0, M_48=0.0, M_49=0.0, M_5=0.0, M_50=0.0, M_51=0.0, M_52=0.0, M_53=0.0, M_54=0.0, M_55=0.0, M_56=0.0, M_57=0.0, M_58=0.0, M_59=0.0, M_6=0.0, M_60=0.0, M_61=0.0, M_62=0.0, M_63=0.0, M_7=0.0, M_8=0.0, M_9=0.0, cost_fn_history_memory=21819, cpu.freq.current=3504, cpu.util.avg_percent_since_last=56.900000, disturbance_history_memory=640, disturbance_transform_state_memory=40, global_step=35, grad_sq_norm=11.792483, loss=0.997140, mem.available=12231589888, mem.percent_used=52.500000, mem.read_bytes_since_boot=250897518592, mem.total=25769803776, mem.used=12331171840, mem.write_bytes_since_boot=286690918400, model_state_memory=16, net.bytes_recv_since_boot=3618453504, net.bytes_sent_since_boot=1552590848, opt_state_memory=29205, param_history_memory=640, param_memory=160, param_sq_norm=144.69375610351562, step_time=0.038923, total_metaopt_memory=29109
# INFO:absl:[40] M_0=-0.10000000149011612, M_1=0.0, M_10=0.0, M_11=0.0, M_12=0.0, M_13=0.0, M_14=0.0, M_15=0.0, M_16=0.0, M_17=0.0, M_18=0.0, M_19=0.0, M_2=0.0, M_20=0.0, M_21=0.0, M_22=0.0, M_23=0.0, M_24=0.0, M_25=0.0, M_26=0.0, M_27=0.0, M_28=0.0, M_29=0.0, M_3=0.0, M_30=0.0, M_31=0.0, M_32=0.0, M_33=0.0, M_34=0.0, M_35=0.0, M_36=0.0, M_37=0.0, M_38=0.0, M_39=0.0, M_4=0.0, M_40=0.0, M_41=0.0, M_42=0.0, M_43=0.0, M_44=0.0, M_45=0.0, M_46=0.0, M_47=0.0, M_48=0.0, M_49=0.0, M_5=0.0, M_50=0.0, M_51=0.0, M_52=0.0, M_53=0.0, M_54=0.0, M_55=0.0, M_56=0.0, M_57=0.0, M_58=0.0, M_59=0.0, M_6=0.0, M_60=0.0, M_61=0.0, M_62=0.0, M_63=0.0, M_7=0.0, M_8=0.0, M_9=0.0, cost_fn_history_memory=21819, cpu.freq.current=3504, cpu.util.avg_percent_since_last=64.500000, disturbance_history_memory=640, disturbance_transform_state_memory=40, global_step=40, grad_sq_norm=7.100474, loss=0.894740, mem.available=12231278592, mem.percent_used=52.500000, mem.read_bytes_since_boot=250897518592, mem.total=25769803776, mem.used=12331008000, mem.write_bytes_since_boot=286690926592, model_state_memory=16, net.bytes_recv_since_boot=3618463744, net.bytes_sent_since_boot=1552601088, opt_state_memory=29205, param_history_memory=640, param_memory=160, param_sq_norm=145.64114379882812, step_time=0.039607, total_metaopt_memory=29109
# INFO:absl:[45] M_0=-0.10000000149011612, M_1=0.0, M_10=0.0, M_11=0.0, M_12=0.0, M_13=0.0, M_14=0.0, M_15=0.0, M_16=0.0, M_17=0.0, M_18=0.0, M_19=0.0, M_2=0.0, M_20=0.0, M_21=0.0, M_22=0.0, M_23=0.0, M_24=0.0, M_25=0.0, M_26=0.0, M_27=0.0, M_28=0.0, M_29=0.0, M_3=0.0, M_30=0.0, M_31=0.0, M_32=0.0, M_33=0.0, M_34=0.0, M_35=0.0, M_36=0.0, M_37=0.0, M_38=0.0, M_39=0.0, M_4=0.0, M_40=0.0, M_41=0.0, M_42=0.0, M_43=0.0, M_44=0.0, M_45=0.0, M_46=0.0, M_47=0.0, M_48=0.0, M_49=0.0, M_5=0.0, M_50=0.0, M_51=0.0, M_52=0.0, M_53=0.0, M_54=0.0, M_55=0.0, M_56=0.0, M_57=0.0, M_58=0.0, M_59=0.0, M_6=0.0, M_60=0.0, M_61=0.0, M_62=0.0, M_63=0.0, M_7=0.0, M_8=0.0, M_9=0.0, cost_fn_history_memory=21819, cpu.freq.current=3504, cpu.util.avg_percent_since_last=63.300000, disturbance_history_memory=640, disturbance_transform_state_memory=40, global_step=45, grad_sq_norm=9.867792, loss=0.872808, mem.available=12233932800, mem.percent_used=52.500000, mem.read_bytes_since_boot=250897518592, mem.total=25769803776, mem.used=12328747008, mem.write_bytes_since_boot=286690934784, model_state_memory=16, net.bytes_recv_since_boot=3618472960, net.bytes_sent_since_boot=1552610304, opt_state_memory=29205, param_history_memory=640, param_memory=160, param_sq_norm=146.61431884765625, step_time=0.040599, total_metaopt_memory=29109
# INFO:absl:[50] M_0=-0.10000000149011612, M_1=0.0, M_10=0.0, M_11=0.0, M_12=0.0, M_13=0.0, M_14=0.0, M_15=0.0, M_16=0.0, M_17=0.0, M_18=0.0, M_19=0.0, M_2=0.0, M_20=0.0, M_21=0.0, M_22=0.0, M_23=0.0, M_24=0.0, M_25=0.0, M_26=0.0, M_27=0.0, M_28=0.0, M_29=0.0, M_3=0.0, M_30=0.0, M_31=0.0, M_32=0.0, M_33=0.0, M_34=0.0, M_35=0.0, M_36=0.0, M_37=0.0, M_38=0.0, M_39=0.0, M_4=0.0, M_40=0.0, M_41=0.0, M_42=0.0, M_43=0.0, M_44=0.0, M_45=0.0, M_46=0.0, M_47=0.0, M_48=0.0, M_49=0.0, M_5=0.0, M_50=0.0, M_51=0.0, M_52=0.0, M_53=0.0, M_54=0.0, M_55=0.0, M_56=0.0, M_57=0.0, M_58=0.0, M_59=0.0, M_6=0.0, M_60=0.0, M_61=0.0, M_62=0.0, M_63=0.0, M_7=0.0, M_8=0.0, M_9=0.0, cost_fn_history_memory=21819, cpu.freq.current=3504, cpu.util.avg_percent_since_last=54.500000, disturbance_history_memory=640, disturbance_transform_state_memory=40, global_step=50, grad_sq_norm=7.466842, loss=0.841758, mem.available=12278431744, mem.percent_used=52.400000, mem.read_bytes_since_boot=250897518592, mem.total=25769803776, mem.used=12284329984, mem.write_bytes_since_boot=286690942976, model_state_memory=16, net.bytes_recv_since_boot=3618481152, net.bytes_sent_since_boot=1552618496, opt_state_memory=29205, param_history_memory=640, param_memory=160, param_sq_norm=147.55606079101562, step_time=0.036744, total_metaopt_memory=29109
# INFO:absl:[55] M_0=-0.10000000149011612, M_1=0.0, M_10=0.0, M_11=0.0, M_12=0.0, M_13=0.0, M_14=0.0, M_15=0.0, M_16=0.0, M_17=0.0, M_18=0.0, M_19=0.0, M_2=0.0, M_20=0.0, M_21=0.0, M_22=0.0, M_23=0.0, M_24=0.0, M_25=0.0, M_26=0.0, M_27=0.0, M_28=0.0, M_29=0.0, M_3=0.0, M_30=0.0, M_31=0.0, M_32=0.0, M_33=0.0, M_34=0.0, M_35=0.0, M_36=0.0, M_37=0.0, M_38=0.0, M_39=0.0, M_4=0.0, M_40=0.0, M_41=0.0, M_42=0.0, M_43=0.0, M_44=0.0, M_45=0.0, M_46=0.0, M_47=0.0, M_48=0.0, M_49=0.0, M_5=0.0, M_50=0.0, M_51=0.0, M_52=0.0, M_53=0.0, M_54=0.0, M_55=0.0, M_56=0.0, M_57=0.0, M_58=0.0, M_59=0.0, M_6=0.0, M_60=0.0, M_61=0.0, M_62=0.0, M_63=0.0, M_7=0.0, M_8=0.0, M_9=0.0, cost_fn_history_memory=21819, cpu.freq.current=3504, cpu.util.avg_percent_since_last=53.300000, disturbance_history_memory=640, disturbance_transform_state_memory=40, global_step=55, grad_sq_norm=8.246340, loss=0.779412, mem.available=12301434880, mem.percent_used=52.300000, mem.read_bytes_since_boot=250897518592, mem.total=25769803776, mem.used=12262768640, mem.write_bytes_since_boot=286690951168, model_state_memory=16, net.bytes_recv_since_boot=3618490368, net.bytes_sent_since_boot=1552627712, opt_state_memory=29205, param_history_memory=640, param_memory=160, param_sq_norm=148.51025390625, step_time=0.037042, total_metaopt_memory=29109
# INFO:absl:[60] M_0=-0.10000000149011612, M_1=0.0, M_10=0.0, M_11=0.0, M_12=0.0, M_13=0.0, M_14=0.0, M_15=0.0, M_16=0.0, M_17=0.0, M_18=0.0, M_19=0.0, M_2=0.0, M_20=0.0, M_21=0.0, M_22=0.0, M_23=0.0, M_24=0.0, M_25=0.0, M_26=0.0, M_27=0.0, M_28=0.0, M_29=0.0, M_3=0.0, M_30=0.0, M_31=0.0, M_32=0.0, M_33=0.0, M_34=0.0, M_35=0.0, M_36=0.0, M_37=0.0, M_38=0.0, M_39=0.0, M_4=0.0, M_40=0.0, M_41=0.0, M_42=0.0, M_43=0.0, M_44=0.0, M_45=0.0, M_46=0.0, M_47=0.0, M_48=0.0, M_49=0.0, M_5=0.0, M_50=0.0, M_51=0.0, M_52=0.0, M_53=0.0, M_54=0.0, M_55=0.0, M_56=0.0, M_57=0.0, M_58=0.0, M_59=0.0, M_6=0.0, M_60=0.0, M_61=0.0, M_62=0.0, M_63=0.0, M_7=0.0, M_8=0.0, M_9=0.0, cost_fn_history_memory=21819, cpu.freq.current=3504, cpu.util.avg_percent_since_last=58.100000, disturbance_history_memory=640, disturbance_transform_state_memory=40, global_step=60, grad_sq_norm=8.682228, loss=0.787497, mem.available=12302893056, mem.percent_used=52.300000, mem.read_bytes_since_boot=250897518592, mem.total=25769803776, mem.used=12259164160, mem.write_bytes_since_boot=286690959360, model_state_memory=16, net.bytes_recv_since_boot=3618498560, net.bytes_sent_since_boot=1552635904, opt_state_memory=29205, param_history_memory=640, param_memory=160, param_sq_norm=149.4503173828125, step_time=0.038170, total_metaopt_memory=29109
# INFO:absl:[65] M_0=-0.10000000149011612, M_1=0.0, M_10=0.0, M_11=0.0, M_12=0.0, M_13=0.0, M_14=0.0, M_15=0.0, M_16=0.0, M_17=0.0, M_18=0.0, M_19=0.0, M_2=0.0, M_20=0.0, M_21=0.0, M_22=0.0, M_23=0.0, M_24=0.0, M_25=0.0, M_26=0.0, M_27=0.0, M_28=0.0, M_29=0.0, M_3=0.0, M_30=0.0, M_31=0.0, M_32=0.0, M_33=0.0, M_34=0.0, M_35=0.0, M_36=0.0, M_37=0.0, M_38=0.0, M_39=0.0, M_4=0.0, M_40=0.0, M_41=0.0, M_42=0.0, M_43=0.0, M_44=0.0, M_45=0.0, M_46=0.0, M_47=0.0, M_48=0.0, M_49=0.0, M_5=0.0, M_50=0.0, M_51=0.0, M_52=0.0, M_53=0.0, M_54=0.0, M_55=0.0, M_56=0.0, M_57=0.0, M_58=0.0, M_59=0.0, M_6=0.0, M_60=0.0, M_61=0.0, M_62=0.0, M_63=0.0, M_7=0.0, M_8=0.0, M_9=0.0, cost_fn_history_memory=21819, cpu.freq.current=3504, cpu.util.avg_percent_since_last=65.000000, disturbance_history_memory=640, disturbance_transform_state_memory=40, global_step=65, grad_sq_norm=9.030681, loss=0.727332, mem.available=12294029312, mem.percent_used=52.300000, mem.read_bytes_since_boot=250897518592, mem.total=25769803776, mem.used=12267732992, mem.write_bytes_since_boot=286690967552, model_state_memory=16, net.bytes_recv_since_boot=3618506752, net.bytes_sent_since_boot=1552645120, opt_state_memory=29205, param_history_memory=640, param_memory=160, param_sq_norm=150.35031127929688, step_time=0.039506, total_metaopt_memory=29109
# INFO:absl:[70] M_0=-0.09979843348264694, M_1=-2.3340191546594724e-05, M_10=0.0009009071509353817, M_11=7.353397086262703e-05, M_12=-0.00019276879902463406, M_13=-0.00041339852032251656, M_14=-0.00022902543423697352, M_15=0.0003101872280240059, M_16=-0.0004138624353799969, M_17=-0.00017469613521825522, M_18=7.632320193806663e-05, M_19=-0.00018252227164339274, M_2=-0.0003766083682421595, M_20=-3.557204399839975e-05, M_21=0.00017848012794274837, M_22=0.00014040578389540315, M_23=-0.0004027489048894495, M_24=0.0004862070200033486, M_25=-8.225225610658526e-05, M_26=0.0002700026088859886, M_27=0.00026816478930413723, M_28=-0.0003707394062075764, M_29=-0.00020586641039699316, M_3=0.0002505806623958051, M_30=0.0006490530213341117, M_31=-0.00014874970656819642, M_32=0.0003910970699507743, M_33=-0.0008105300948955119, M_34=-0.00028442396433092654, M_35=0.00019419778254814446, M_36=-0.00014193481183610857, M_37=-0.00019971260917373002, M_38=-0.0006307585863396525, M_39=0.0011155621614307165, M_4=-8.046760922297835e-05, M_40=-5.912565757171251e-05, M_41=0.00015487306518480182, M_42=0.00043784556328319013, M_43=-0.00025213227490894496, M_44=-0.00036525147152133286, M_45=-2.156739355996251e-05, M_46=0.000754771928768605, M_47=-0.0006092300172895193, M_48=-0.0004436546587385237, M_49=0.00030929225613363087, M_5=-0.0006818457623012364, M_50=0.0006167806568555534, M_51=-0.0013341732556000352, M_52=0.0002985802129842341, M_53=-0.0005181219894438982, M_54=0.0005288384854793549, M_55=-0.0002210670500062406, M_56=0.00011679147428367287, M_57=-0.0001397421001456678, M_58=-0.0007749668438918889, M_59=0.001404680428095162, M_6=0.0004195011861156672, M_60=-4.897176768281497e-05, M_61=0.0008889934397302568, M_62=-0.0009550172253511846, M_63=-0.0006083211628720164, M_7=-0.00012133034033467993, M_8=3.563607606338337e-05, M_9=0.00014931787154637277, cost_fn_history_memory=21819, cpu.freq.current=3504, cpu.util.avg_percent_since_last=49.200000, disturbance_history_memory=640, disturbance_transform_state_memory=40, global_step=70, gpc_cost=0.6573779582977295, grad_M_0=-35.19671630859375, grad_M_1=10.247916221618652, grad_M_10=-8.550739288330078, grad_M_11=-0.05799835920333862, grad_M_12=-38.868709564208984, grad_M_13=6.710110664367676, grad_M_14=-11.017354965209961, grad_M_15=-31.080230712890625, grad_M_16=14.542366981506348, grad_M_17=-11.004846572875977, grad_M_18=2.9163014888763428, grad_M_19=0.24342814087867737, grad_M_2=7.816842555999756, grad_M_20=-5.873961925506592, grad_M_21=-4.636229038238525, grad_M_22=-32.33594512939453, grad_M_23=20.762042999267578, grad_M_24=4.9688215255737305, grad_M_25=9.781610488891602, grad_M_26=-5.2435455322265625, grad_M_27=1.5824763774871826, grad_M_28=19.93808937072754, grad_M_29=24.918581008911133, grad_M_3=11.769028663635254, grad_M_30=-17.25592041015625, grad_M_31=-23.826791763305664, grad_M_32=-15.44725513458252, grad_M_33=29.075206756591797, grad_M_34=26.96846580505371, grad_M_35=-5.736870288848877, grad_M_36=0.31880563497543335, grad_M_37=12.458036422729492, grad_M_38=-12.272842407226562, grad_M_39=-9.383097648620605, grad_M_4=-5.1448516845703125, grad_M_40=2.8661091327667236, grad_M_41=10.45728874206543, grad_M_42=-14.835134506225586, grad_M_43=2.695646047592163, grad_M_44=9.552811622619629, grad_M_45=-30.792560577392578, grad_M_46=-11.484211921691895, grad_M_47=27.943574905395508, grad_M_48=10.672792434692383, grad_M_49=-16.055492401123047, grad_M_5=19.669219970703125, grad_M_50=33.608184814453125, grad_M_51=20.506893157958984, grad_M_52=-30.04680061340332, grad_M_53=3.8973701000213623, grad_M_54=3.20045804977417, grad_M_55=5.3538498878479, grad_M_56=-7.857381820678711, grad_M_57=13.822928428649902, grad_M_58=31.083215713500977, grad_M_59=-4.05620002746582, grad_M_6=-5.512750148773193, grad_M_60=-13.339154243469238, grad_M_61=-26.485929489135742, grad_M_62=33.36849594116211, grad_M_63=10.777573585510254, grad_M_7=20.2283992767334, grad_M_8=3.073171615600586, grad_M_9=-5.233668804168701, grad_sq_norm=8.300724, lo ...
# INFO:absl:[75] M_0=-0.1004076674580574, M_1=-0.00028729051700793207, M_10=0.001171894371509552, M_11=0.00013385330385062844, M_12=-0.0003166295646224171, M_13=-0.0006611134158447385, M_14=-2.3355576558969915e-05, M_15=0.00036198971793055534, M_16=-0.00010108750575454906, M_17=0.0010147050488740206, M_18=-0.0007041168282739818, M_19=-0.00020207335182931274, M_2=-0.000716410402674228, M_20=-0.0004496364272199571, M_21=0.00021190686675254256, M_22=0.0003754878416657448, M_23=-0.0005198554717935622, M_24=0.0007061974029056728, M_25=0.00030152517138049006, M_26=0.00046772407949902117, M_27=0.00033465129672549665, M_28=-0.00026093990891240537, M_29=-0.00015561567852273583, M_3=6.557762390002608e-05, M_30=1.998247353185434e-05, M_31=8.909385360311717e-05, M_32=0.0006488682702183723, M_33=-0.0006098035373724997, M_34=0.0006055171834304929, M_35=-0.0002244865318061784, M_36=-0.00047982216347008944, M_37=-0.0007012071437202394, M_38=-0.0005078873364254832, M_39=0.0012552158441394567, M_4=0.0005549826892092824, M_40=-0.0007761509041301906, M_41=-0.0003246445849072188, M_42=0.0004289677017368376, M_43=-0.0006623213994316757, M_44=-4.080189683008939e-06, M_45=-0.00014287707745097578, M_46=0.0014835236361250281, M_47=-0.001279416843317449, M_48=-0.0001869607367552817, M_49=0.0006346027366816998, M_5=-0.0011093583889305592, M_50=0.00044500245712697506, M_51=-0.0015788445016369224, M_52=0.0011481012916192412, M_53=-3.1143797968979925e-05, M_54=-0.0007412005797959864, M_55=0.000652610557153821, M_56=-0.00041436965693719685, M_57=0.0004420042096171528, M_58=-0.0015483131865039468, M_59=0.0007189850439317524, M_6=3.97857693315018e-05, M_60=0.0004020835040137172, M_61=0.0007077629561536014, M_62=-0.00031608142307959497, M_63=-0.0008623242611065507, M_7=-0.0007565878331661224, M_8=0.0004885365488007665, M_9=7.902320066932589e-05, cost_fn_history_memory=21819, cpu.freq.current=3504, cpu.util.avg_percent_since_last=0.000000, disturbance_history_memory=640, disturbance_transform_state_memory=40, global_step=75, gpc_cost=0.6500892043113708, grad_M_0=-3.136791229248047, grad_M_1=20.425607681274414, grad_M_10=-31.149513244628906, grad_M_11=-2.1844685077667236, grad_M_12=-10.72118091583252, grad_M_13=21.94788360595703, grad_M_14=3.8667612075805664, grad_M_15=4.64838171005249, grad_M_16=2.7680225372314453, grad_M_17=-11.976158142089844, grad_M_18=17.24765968322754, grad_M_19=8.231912612915039, grad_M_2=-5.850548267364502, grad_M_20=-8.137432098388672, grad_M_21=-1.9273377656936646, grad_M_22=-6.627220153808594, grad_M_23=0.5149996876716614, grad_M_24=-6.5673699378967285, grad_M_25=7.411929607391357, grad_M_26=-14.04567813873291, grad_M_27=-17.58164405822754, grad_M_28=-2.8146300315856934, grad_M_29=5.468201160430908, grad_M_3=-13.113585472106934, grad_M_30=-6.9164886474609375, grad_M_31=1.4843928813934326, grad_M_32=-12.253010749816895, grad_M_33=-0.8375328779220581, grad_M_34=2.3442654609680176, grad_M_35=23.0361328125, grad_M_36=-7.196264743804932, grad_M_37=-4.6615142822265625, grad_M_38=8.185839653015137, grad_M_39=-13.309815406799316, grad_M_4=-2.4498987197875977, grad_M_40=20.45909309387207, grad_M_41=10.994490623474121, grad_M_42=5.9190497398376465, grad_M_43=7.950774669647217, grad_M_44=9.021360397338867, grad_M_45=-5.565195560455322, grad_M_46=-13.177245140075684, grad_M_47=-0.8345471024513245, grad_M_48=14.982918739318848, grad_M_49=2.142803907394409, grad_M_5=-11.68313217163086, grad_M_50=35.12635040283203, grad_M_51=12.845898628234863, grad_M_52=-5.238351821899414, grad_M_53=-13.561396598815918, grad_M_54=10.783586502075195, grad_M_55=-10.334406852722168, grad_M_56=23.090511322021484, grad_M_57=-20.721481323242188, grad_M_58=13.397031784057617, grad_M_59=7.972178936004639, grad_M_6=-13.075211524963379, grad_M_60=-24.843225479125977, grad_M_61=-4.011510848999023, grad_M_62=-19.225574493408203, grad_M_63=24.607831954956055, grad_M_7=18.272876739501953, grad_M_8=9.821853637695312, grad_M_9=9.156916618347168, grad_sq_norm=6.470540, loss=0.640066,  ...
# INFO:absl:[80] M_0=-0.10033988952636719, M_1=-2.297383844052092e-06, M_10=0.0013755183899775147, M_11=0.0003266314452048391, M_12=-0.0010163409169763327, M_13=-0.0004191356129013002, M_14=-4.367341171018779e-05, M_15=-3.443832974880934e-05, M_16=6.911621312610805e-05, M_17=0.0010834281565621495, M_18=-0.0001401244371663779, M_19=-0.0005364745738916099, M_2=-0.0007911300635896623, M_20=-0.0005997550906613469, M_21=0.0009462656453251839, M_22=4.730281580123119e-05, M_23=-0.0007549547590315342, M_24=0.0011100703850388527, M_25=4.832732520299032e-05, M_26=0.00025056695449166, M_27=0.00047197332605719566, M_28=-0.0004458754847291857, M_29=-0.00030267221154645085, M_3=0.00041609996696934104, M_30=-0.000676825933624059, M_31=-0.00019289964984636754, M_32=0.0010268575279042125, M_33=-0.0007671353523619473, M_34=0.0005393660394474864, M_35=-0.0002576516999397427, M_36=-0.0001730747171677649, M_37=-0.0005201798630878329, M_38=-0.0011667570797726512, M_39=0.0009735199855640531, M_4=0.000580247666221112, M_40=-0.0012110740644857287, M_41=0.00022655566863249987, M_42=0.0008076412486843765, M_43=-0.0009216778562404215, M_44=0.00026432928279973567, M_45=-0.0001737278507789597, M_46=0.0021116172429174185, M_47=-0.002187877194955945, M_48=-0.00044093019096180797, M_49=0.0006655596080236137, M_5=-0.0008085969020612538, M_50=0.0007486420217901468, M_51=-0.0018430242780596018, M_52=0.001125558279454708, M_53=0.00025256405933760107, M_54=-3.190161442034878e-05, M_55=0.000729782332200557, M_56=-0.0006561587215401232, M_57=0.00024048831255640835, M_58=-0.00105767953209579, M_59=0.0002290841657668352, M_6=0.0001715045073069632, M_60=0.00033017704845406115, M_61=-1.2506114217103459e-05, M_62=-0.0002200271701440215, M_63=-0.0003100684843957424, M_7=-0.000990619882941246, M_8=0.0002577339473646134, M_9=-6.756704533472657e-05, cost_fn_history_memory=21819, cpu.freq.current=3504, cpu.util.avg_percent_since_last=48.500000, disturbance_history_memory=640, disturbance_transform_state_memory=40, global_step=80, gpc_cost=0.6596654653549194, grad_M_0=-0.695671021938324, grad_M_1=9.305633544921875, grad_M_10=11.846197128295898, grad_M_11=2.575634479522705, grad_M_12=20.605865478515625, grad_M_13=0.7050960063934326, grad_M_14=-9.487581253051758, grad_M_15=-9.767200469970703, grad_M_16=-4.60744571685791, grad_M_17=-18.708362579345703, grad_M_18=34.46012878417969, grad_M_19=-7.614564418792725, grad_M_2=-2.4170823097229004, grad_M_20=0.12819534540176392, grad_M_21=-7.302240371704102, grad_M_22=34.809173583984375, grad_M_23=5.053150177001953, grad_M_24=-10.887126922607422, grad_M_25=28.139020919799805, grad_M_26=7.935331344604492, grad_M_27=-31.27490997314453, grad_M_28=29.897018432617188, grad_M_29=5.6599860191345215, grad_M_3=-27.516820907592773, grad_M_30=25.656553268432617, grad_M_31=11.972981452941895, grad_M_32=-29.88267707824707, grad_M_33=-12.626655578613281, grad_M_34=3.4211268424987793, grad_M_35=-35.758548736572266, grad_M_36=3.208495855331421, grad_M_37=-7.2835516929626465, grad_M_38=13.543128967285156, grad_M_39=7.249146461486816, grad_M_4=30.837093353271484, grad_M_40=12.279312133789062, grad_M_41=-13.893702507019043, grad_M_42=-0.8683381080627441, grad_M_43=-30.215065002441406, grad_M_44=2.897989511489868, grad_M_45=1.7451369762420654, grad_M_46=-13.173994064331055, grad_M_47=69.9000473022461, grad_M_48=-25.466615676879883, grad_M_49=7.760016918182373, grad_M_5=-32.504920959472656, grad_M_50=13.198662757873535, grad_M_51=5.799027442932129, grad_M_52=-31.313756942749023, grad_M_53=9.41419506072998, grad_M_54=-18.227880477905273, grad_M_55=6.808313846588135, grad_M_56=8.725593566894531, grad_M_57=32.856754302978516, grad_M_58=-31.578079223632812, grad_M_59=-3.4215240478515625, grad_M_6=-17.0176944732666, grad_M_60=-9.05905818939209, grad_M_61=18.95762825012207, grad_M_62=50.172000885009766, grad_M_63=-6.326502799987793, grad_M_7=18.227209091186523, grad_M_8=-7.6514129638671875, grad_M_9=-15.365865707397461, grad_sq_norm=8.529959, loss=0.654818, mem.avail ...
# INFO:absl:[85] M_0=-0.10080090165138245, M_1=-0.0005070999031886458, M_10=0.0011902626138180494, M_11=0.00013507042604032904, M_12=-0.0003763636341318488, M_13=-0.0007435191655531526, M_14=0.0006217164336703718, M_15=0.0006361175328493118, M_16=0.0008913289639167488, M_17=0.0004610797041095793, M_18=0.00021389714675024152, M_19=9.55825307755731e-05, M_2=-0.001084812916815281, M_20=-5.652065283356933e-06, M_21=0.0008183124591596425, M_22=-0.0002621085150167346, M_23=-0.0008645494235679507, M_24=0.0010007915552705526, M_25=-0.00047668334445916116, M_26=0.00019813088874798268, M_27=-0.00012929923832416534, M_28=-0.0007911525317467749, M_29=1.5456922483281232e-05, M_3=-0.00032400377676822245, M_30=-4.05359169235453e-05, M_31=0.0002150709624402225, M_32=0.0012794892536476254, M_33=-0.0012322745751589537, M_34=0.001182091305963695, M_35=-0.0005069681792519987, M_36=-0.000479877955513075, M_37=-0.0005690449615940452, M_38=-0.0009684794931672513, M_39=0.00045835887431167066, M_4=0.0006442088633775711, M_40=-0.0011298111639916897, M_41=0.0005811782320961356, M_42=0.0005855273921042681, M_43=-0.0012781869154423475, M_44=0.000130858548800461, M_45=-0.00026225741021335125, M_46=0.0016855320427566767, M_47=-0.0012360173277556896, M_48=-0.0007386648212559521, M_49=0.00029216267284937203, M_5=0.0003028910723514855, M_50=0.0008078066748566926, M_51=-0.0009519041632302105, M_52=0.0008076365338638425, M_53=-1.0856348126253579e-05, M_54=-0.0002982885926030576, M_55=0.0012828944018110633, M_56=-0.0007502677035517991, M_57=-0.00011913499474758282, M_58=-0.0009431669022887945, M_59=-2.5180281227221712e-05, M_6=5.6626711739227176e-05, M_60=-0.0002108995249727741, M_61=0.00013153404870536178, M_62=-0.00043690562597475946, M_63=-0.00014842134260106832, M_7=-0.001119986642152071, M_8=0.00010804036719491705, M_9=0.0004938113270327449, cost_fn_history_memory=21819, cpu.freq.current=3504, cpu.util.avg_percent_since_last=40.500000, disturbance_history_memory=640, disturbance_transform_state_memory=40, global_step=85, gpc_cost=0.6522694826126099, grad_M_0=24.571348190307617, grad_M_1=10.676312446594238, grad_M_10=-8.838497161865234, grad_M_11=-4.446065425872803, grad_M_12=-13.34038257598877, grad_M_13=-6.673983097076416, grad_M_14=-8.414068222045898, grad_M_15=-17.12178611755371, grad_M_16=-12.062257766723633, grad_M_17=3.8714332580566406, grad_M_18=0.24622666835784912, grad_M_19=-1.2011266946792603, grad_M_2=20.794462203979492, grad_M_20=-10.186542510986328, grad_M_21=-9.323809623718262, grad_M_22=41.163902282714844, grad_M_23=-36.04533004760742, grad_M_24=13.346147537231445, grad_M_25=8.495351791381836, grad_M_26=21.414976119995117, grad_M_27=9.453871726989746, grad_M_28=-1.9586539268493652, grad_M_29=-15.59837532043457, grad_M_3=19.321083068847656, grad_M_30=-3.950474739074707, grad_M_31=-13.184328079223633, grad_M_32=-10.718183517456055, grad_M_33=-1.1297955513000488, grad_M_34=6.039024353027344, grad_M_35=-15.343692779541016, grad_M_36=10.57861042022705, grad_M_37=4.935607433319092, grad_M_38=-0.8894881010055542, grad_M_39=-10.63333511352539, grad_M_4=-10.674251556396484, grad_M_40=27.944860458374023, grad_M_41=-17.19947624206543, grad_M_42=-11.5112943649292, grad_M_43=17.667383193969727, grad_M_44=2.054508686065674, grad_M_45=4.128318786621094, grad_M_46=-14.55765438079834, grad_M_47=2.656604766845703, grad_M_48=-1.0545355081558228, grad_M_49=-11.814309120178223, grad_M_5=-36.99604797363281, grad_M_50=21.669355392456055, grad_M_51=2.040262222290039, grad_M_52=-1.5211827754974365, grad_M_53=14.602535247802734, grad_M_54=-7.955526351928711, grad_M_55=8.29051685333252, grad_M_56=-2.7747464179992676, grad_M_57=5.6142258644104, grad_M_58=-13.048809051513672, grad_M_59=-11.159775733947754, grad_M_6=1.7564167976379395, grad_M_60=27.888198852539062, grad_M_61=-16.162506103515625, grad_M_62=31.661884307861328, grad_M_63=-20.887056350708008, grad_M_7=-12.291329383850098, grad_M_8=-9.141175270080566, grad_M_9=12.25184154510498, grad_sq_norm=8.881439, loss=0.6713 ...
# INFO:absl:[90] M_0=-0.10090191662311554, M_1=-5.0817114242818207e-05, M_10=0.001299705938436091, M_11=0.00018626249220687896, M_12=-0.0006681348895654082, M_13=-0.00040061608888208866, M_14=0.00012842311116401106, M_15=0.0010378080187365413, M_16=0.0010206623701378703, M_17=0.0004885871894657612, M_18=-0.0004083024978172034, M_19=0.0002868326264433563, M_2=-0.0004591252945829183, M_20=-0.00011247691872995347, M_21=0.0016171711031347513, M_22=-0.0005503675783984363, M_23=-0.0013706146273761988, M_24=0.0013682242715731263, M_25=-0.0002040673280134797, M_26=0.0008058829698711634, M_27=-0.0004054777091369033, M_28=-0.001174644916318357, M_29=-0.00011900543904630467, M_3=-0.0005566312465816736, M_30=0.0007377109723165631, M_31=0.00027759693330153823, M_32=0.001107458840124309, M_33=-0.0007088864222168922, M_34=0.0010998802026733756, M_35=-0.0004404922074172646, M_36=-0.0004896018072031438, M_37=0.000211384569411166, M_38=-0.000874132092576474, M_39=0.0004629289614968002, M_4=0.00016592239262536168, M_40=-0.0016006875084713101, M_41=0.0004943526000715792, M_42=0.00020756004960276186, M_43=-0.0013538326602429152, M_44=-0.00016976805636659265, M_45=-0.001146466238424182, M_46=0.0017784549854695797, M_47=-0.0008308607502840459, M_48=-0.00045057712122797966, M_49=0.0003659177746158093, M_5=0.00048536196118220687, M_50=0.0005733618745580316, M_51=-0.0003330121107865125, M_52=0.0013408772647380829, M_53=-0.0006070644594728947, M_54=-0.00047302007442340255, M_55=0.0015572735574096441, M_56=-0.0013395539717748761, M_57=-0.0003847201296593994, M_58=0.0004130683373659849, M_59=-0.0008360404754057527, M_6=0.0007079457864165306, M_60=-1.8137394363293424e-05, M_61=-6.707150168949738e-05, M_62=-0.0005997884436510503, M_63=-0.0009113309206441045, M_7=-0.001345441909506917, M_8=-3.314049172331579e-05, M_9=0.0004590514290612191, cost_fn_history_memory=21819, cpu.freq.current=3504, cpu.util.avg_percent_since_last=45.800000, disturbance_history_memory=640, disturbance_transform_state_memory=40, global_step=90, gpc_cost=0.5864725708961487, grad_M_0=17.564619064331055, grad_M_1=-17.38267707824707, grad_M_10=6.228856563568115, grad_M_11=-7.801586151123047, grad_M_12=5.950103759765625, grad_M_13=-8.590429306030273, grad_M_14=1.1668250560760498, grad_M_15=0.8862125277519226, grad_M_16=-5.375181198120117, grad_M_17=-12.641310691833496, grad_M_18=-2.9600677490234375, grad_M_19=-5.198293685913086, grad_M_2=1.396026611328125, grad_M_20=10.946508407592773, grad_M_21=11.631075859069824, grad_M_22=20.89868927001953, grad_M_23=-4.9074811935424805, grad_M_24=7.88672399520874, grad_M_25=-0.08749771118164062, grad_M_26=-6.935763359069824, grad_M_27=-8.737797737121582, grad_M_28=21.577062606811523, grad_M_29=-15.21743106842041, grad_M_3=-26.051542282104492, grad_M_30=5.507948398590088, grad_M_31=-10.526632308959961, grad_M_32=2.7362470626831055, grad_M_33=-2.4435291290283203, grad_M_34=-5.943946361541748, grad_M_35=-2.134383201599121, grad_M_36=14.69803237915039, grad_M_37=-2.7916696071624756, grad_M_38=5.057525634765625, grad_M_39=4.898955821990967, grad_M_4=16.464550018310547, grad_M_40=-12.744721412658691, grad_M_41=-9.747841835021973, grad_M_42=-0.8414880633354187, grad_M_43=6.836674690246582, grad_M_44=-0.2182740420103073, grad_M_45=18.197467803955078, grad_M_46=-10.845564842224121, grad_M_47=-6.549810409545898, grad_M_48=-5.218206405639648, grad_M_49=3.1180248260498047, grad_M_5=-0.7907892465591431, grad_M_50=-2.070380926132202, grad_M_51=-6.993417263031006, grad_M_52=-17.875112533569336, grad_M_53=4.328283309936523, grad_M_54=1.7871595621109009, grad_M_55=-14.064001083374023, grad_M_56=15.840209007263184, grad_M_57=2.4021944999694824, grad_M_58=-18.807758331298828, grad_M_59=26.667694091796875, grad_M_6=20.674365997314453, grad_M_60=26.435670852661133, grad_M_61=-4.523573875427246, grad_M_62=0.2640342116355896, grad_M_63=5.779387474060059, grad_M_7=-6.071901321411133, grad_M_8=3.347724437713623, grad_M_9=-8.189563751220703, grad_sq_norm=8.191960, loss=0.588816, ...
# INFO:absl:[95] M_0=-0.10094679892063141, M_1=-0.0006465425249189138, M_10=0.001981325214728713, M_11=0.0005302731296978891, M_12=-0.00043180680950172246, M_13=-1.851803608587943e-05, M_14=0.0003252121969126165, M_15=0.0012594122672453523, M_16=0.0005338912596926093, M_17=0.0016019624890759587, M_18=-0.00040911129326559603, M_19=-0.0004978382494300604, M_2=-0.0011071793269366026, M_20=-0.0003670387377496809, M_21=0.0019680268596857786, M_22=-0.0006136787706054747, M_23=-0.0016525699757039547, M_24=0.0015684241661801934, M_25=-0.0006002715672366321, M_26=0.0004003493522759527, M_27=6.143130303826183e-05, M_28=-0.0014783930964767933, M_29=0.0007606240105815232, M_3=-0.00022574419563170522, M_30=0.000851475284434855, M_31=0.00035523291444405913, M_32=0.0012856071116402745, M_33=-0.000455633009551093, M_34=0.001176174613647163, M_35=-0.00018438842380419374, M_36=-0.001034687040373683, M_37=-0.0004147478030063212, M_38=-0.0004323982575442642, M_39=0.0013111790176481009, M_4=-0.00029854816966690123, M_40=-0.0017003171378746629, M_41=0.0002298442559549585, M_42=0.0007449656841345131, M_43=-0.0019556162878870964, M_44=-0.00034531179699115455, M_45=-0.0010769290383905172, M_46=0.00163149437867105, M_47=-0.00043335490045137703, M_48=-0.00040619747596792877, M_49=0.000550595170352608, M_5=-0.00013566621055360883, M_50=0.0004925939138047397, M_51=-0.0006147576496005058, M_52=0.0010654710931703448, M_53=-0.0010892953723669052, M_54=-0.0003019044816028327, M_55=0.0017186099430546165, M_56=-0.0013147764839231968, M_57=-0.0007202400593087077, M_58=0.0007330841035582125, M_59=-0.001844506710767746, M_6=0.0007929061539471149, M_60=0.000437660317402333, M_61=0.0003512820112518966, M_62=-0.0006610650452785194, M_63=-0.0008099746773950756, M_7=-0.0009512379765510559, M_8=-0.0002496789093129337, M_9=-8.315649029100314e-05, cost_fn_history_memory=21819, cpu.freq.current=3504, cpu.util.avg_percent_since_last=39.900000, disturbance_history_memory=640, disturbance_transform_state_memory=40, global_step=95, gpc_cost=0.5686049461364746, grad_M_0=-52.341712951660156, grad_M_1=-16.592260360717773, grad_M_10=-16.30868911743164, grad_M_11=-5.690619468688965, grad_M_12=9.352846145629883, grad_M_13=-0.8638080954551697, grad_M_14=-17.433956146240234, grad_M_15=-8.889705657958984, grad_M_16=8.533775329589844, grad_M_17=-2.2879443168640137, grad_M_18=6.638782978057861, grad_M_19=0.9367740154266357, grad_M_2=36.42283248901367, grad_M_20=-21.22258758544922, grad_M_21=7.517285346984863, grad_M_22=12.87040901184082, grad_M_23=0.08170752227306366, grad_M_24=5.105828285217285, grad_M_25=-10.497469902038574, grad_M_26=-4.235286712646484, grad_M_27=-54.765323638916016, grad_M_28=-26.877687454223633, grad_M_29=-4.877165794372559, grad_M_3=3.0168492794036865, grad_M_30=51.2104377746582, grad_M_31=-7.840723991394043, grad_M_32=37.635562896728516, grad_M_33=-47.01968765258789, grad_M_34=-12.367881774902344, grad_M_35=20.918638229370117, grad_M_36=-14.722466468811035, grad_M_37=-18.78255844116211, grad_M_38=-0.9685866832733154, grad_M_39=-0.17248404026031494, grad_M_4=23.190576553344727, grad_M_40=4.942873954772949, grad_M_41=-19.46031951904297, grad_M_42=14.031825065612793, grad_M_43=11.469447135925293, grad_M_44=-12.582547187805176, grad_M_45=22.58528709411621, grad_M_46=-3.6565439701080322, grad_M_47=-16.477142333984375, grad_M_48=1.4607744216918945, grad_M_49=4.1808342933654785, grad_M_5=11.816045761108398, grad_M_50=19.22374153137207, grad_M_51=4.182039260864258, grad_M_52=20.558210372924805, grad_M_53=-6.876833438873291, grad_M_54=-12.535438537597656, grad_M_55=15.028448104858398, grad_M_56=-11.136237144470215, grad_M_57=4.574460029602051, grad_M_58=0.06319978833198547, grad_M_59=24.576446533203125, grad_M_6=2.2772433757781982, grad_M_60=9.12110710144043, grad_M_61=-1.7941807508468628, grad_M_62=-44.09221649169922, grad_M_63=27.325353622436523, grad_M_7=-1.307740569114685, grad_M_8=5.615056991577148, grad_M_9=-4.442310333251953, grad_sq_norm=6.130467, loss=0.553641, mem. ...
# ...
# INFO:absl:[195] M_0=-0.10016406327486038, M_1=-0.00026343658100813627, M_10=0.0018666592659428716, M_11=-0.002291829790920019, M_12=-0.001364232855848968, M_13=-0.0028365557081997395, M_14=-0.0017933491617441177, M_15=0.0020266396459192038, M_16=0.0012331930920481682, M_17=0.0029026654083281755, M_18=-0.001828426611609757, M_19=-0.0005834674811922014, M_2=-0.0005590458167716861, M_20=0.0010466756066307425, M_21=0.0014215048868209124, M_22=-0.0029210662469267845, M_23=0.0002894178905989975, M_24=0.00028089445549994707, M_25=0.00015219081251416355, M_26=0.002068498870357871, M_27=-0.0002929254260379821, M_28=-0.0023991791531443596, M_29=-0.0016868197126314044, M_3=-0.0006999614997766912, M_30=0.001515984651632607, M_31=0.00018258014461025596, M_32=-0.0005941186682321131, M_33=0.0022581901866942644, M_34=0.0009114858112297952, M_35=-0.0026121027767658234, M_36=-0.0006020301370881498, M_37=0.001980819972231984, M_38=0.004769954830408096, M_39=0.0002220567112090066, M_4=-0.00019862641056533903, M_40=-0.0017550067277625203, M_41=0.002055616118013859, M_42=0.000313118303893134, M_43=-0.0003571094130165875, M_44=0.0027474677190184593, M_45=-0.00220557046122849, M_46=0.00027171289548277855, M_47=-0.0012223540106788278, M_48=-0.00028239679522812366, M_49=0.001487808651290834, M_5=-0.0029317110311239958, M_50=-0.002213818486779928, M_51=-0.001339864800684154, M_52=0.0029186871834099293, M_53=-0.0029327436350286007, M_54=-0.002171439118683338, M_55=0.0007491439464502037, M_56=-0.004873570520430803, M_57=-0.0008142513106577098, M_58=0.0006955487187951803, M_59=0.001839608303271234, M_6=0.0014796874020248652, M_60=0.0009943172335624695, M_61=0.001003432204015553, M_62=4.181358963251114e-05, M_63=-0.0015879046404734254, M_7=0.0007252436480484903, M_8=0.003391863079741597, M_9=-0.0005352935404516757, cost_fn_history_memory=21819, cpu.freq.current=3504, cpu.util.avg_percent_since_last=51.400000, disturbance_history_memory=640, disturbance_transform_state_memory=40, global_step=195, gpc_cost=0.49814411997795105, grad_M_0=3.5844969749450684, grad_M_1=-7.777034759521484, grad_M_10=-0.27176806330680847, grad_M_11=-20.50148582458496, grad_M_12=20.861148834228516, grad_M_13=-11.426007270812988, grad_M_14=7.774098873138428, grad_M_15=-8.352434158325195, grad_M_16=11.34714126586914, grad_M_17=-3.9323856830596924, grad_M_18=-8.858986854553223, grad_M_19=18.50250244140625, grad_M_2=-0.24090421199798584, grad_M_20=-26.251558303833008, grad_M_21=17.406923294067383, grad_M_22=-5.18261194229126, grad_M_23=8.797587394714355, grad_M_24=6.179407596588135, grad_M_25=-1.4107424020767212, grad_M_26=5.13119649887085, grad_M_27=5.709831237792969, grad_M_28=1.528071641921997, grad_M_29=4.25923490524292, grad_M_3=7.496030330657959, grad_M_30=2.233760118484497, grad_M_31=-14.099281311035156, grad_M_32=-10.452672958374023, grad_M_33=6.376469612121582, grad_M_34=-11.812463760375977, grad_M_35=-19.890623092651367, grad_M_36=-1.0513396263122559, grad_M_37=-7.744862079620361, grad_M_38=11.316129684448242, grad_M_39=-11.882707595825195, grad_M_4=4.164097309112549, grad_M_40=-3.0683441162109375, grad_M_41=12.711877822875977, grad_M_42=-10.830883026123047, grad_M_43=-0.23315587639808655, grad_M_44=-3.9505560398101807, grad_M_45=5.149540424346924, grad_M_46=-16.60527229309082, grad_M_47=-9.88599681854248, grad_M_48=10.042445182800293, grad_M_49=-9.449336051940918, grad_M_5=2.3284945487976074, grad_M_50=11.904129028320312, grad_M_51=-3.173839807510376, grad_M_52=1.8183293342590332, grad_M_53=-0.6068006157875061, grad_M_54=-1.9127445220947266, grad_M_55=-2.2147655487060547, grad_M_56=-7.447871208190918, grad_M_57=-9.88863468170166, grad_M_58=-12.050922393798828, grad_M_59=-14.55001449584961, grad_M_6=0.5847653150558472, grad_M_60=-9.154454231262207, grad_M_61=-17.949430465698242, grad_M_62=15.248226165771484, grad_M_63=27.60515785217285, grad_M_7=-26.913890838623047, grad_M_8=25.49187660217285, grad_M_9=4.577035427093506, grad_sq_norm=7.559606, loss=0.506157, mem.available=12372 ...
# INFO:absl:[199] M_0=-0.10064609348773956, M_1=-0.00024745965492911637, M_10=0.0016727595357224345, M_11=-0.002136352239176631, M_12=-0.0015806766459718347, M_13=-0.002835293998941779, M_14=-0.001200997270643711, M_15=0.0014558552065864205, M_16=0.0013599359663203359, M_17=0.0031841162126511335, M_18=-0.002000714186578989, M_19=-0.0002033065538853407, M_2=-0.0007462158682756126, M_20=0.0009400450508110225, M_21=0.0016658795066177845, M_22=-0.0032317994628101587, M_23=0.0003639866772573441, M_24=-2.224819218099583e-05, M_25=0.00015386006271000952, M_26=0.0026094471104443073, M_27=-4.172704939264804e-05, M_28=-0.002419073833152652, M_29=-0.002273645717650652, M_3=-0.0011860812082886696, M_30=0.0014127608155831695, M_31=0.00028255960205569863, M_32=-5.621722812065855e-05, M_33=0.0028373163659125566, M_34=0.0007503716624341905, M_35=-0.002720290794968605, M_36=-0.0005856544012203813, M_37=0.0019400331657379866, M_38=0.004966287408024073, M_39=0.00022873700072523206, M_4=0.00046015658881515265, M_40=-0.0018074095714837313, M_41=0.0021846131421625614, M_42=0.0008399959770031273, M_43=-0.0004188716702628881, M_44=0.0025025068316608667, M_45=-0.0020165848545730114, M_46=0.0006115699070505798, M_47=-0.0007585324929095805, M_48=-0.000564230140298605, M_49=0.0010815870482474566, M_5=-0.0027346923016011715, M_50=-0.002214273903518915, M_51=-0.0014074713690206409, M_52=0.0025227877777069807, M_53=-0.0030618510209023952, M_54=-0.0022237193770706654, M_55=0.0005806774133816361, M_56=-0.005059351678937674, M_57=-0.0010603414848446846, M_58=0.0007809909293428063, M_59=0.0019835142884403467, M_6=0.0008766540559008718, M_60=0.0011036210926249623, M_61=0.0011298585450276732, M_62=0.000152453183545731, M_63=-0.0016154542099684477, M_7=0.0006670306902378798, M_8=0.0037812525406479836, M_9=-0.0004640338011085987, cost_fn_history_memory=21819, cpu.freq.current=3504, cpu.util.avg_percent_since_last=46.400000, disturbance_history_memory=640, disturbance_transform_state_memory=40, global_step=199, gpc_cost=0.43821480870246887, grad_M_0=9.347968101501465, grad_M_1=5.140035629272461, grad_M_10=-2.597876787185669, grad_M_11=9.700479507446289, grad_M_12=15.88331413269043, grad_M_13=-4.556841850280762, grad_M_14=-6.601056098937988, grad_M_15=3.843928813934326, grad_M_16=-4.868152141571045, grad_M_17=-1.9545471668243408, grad_M_18=-3.045198917388916, grad_M_19=1.8190550804138184, grad_M_2=7.24913215637207, grad_M_20=-2.603597402572632, grad_M_21=0.20670659840106964, grad_M_22=-1.5813652276992798, grad_M_23=4.988264560699463, grad_M_24=3.1552212238311768, grad_M_25=-5.832605838775635, grad_M_26=0.5852075815200806, grad_M_27=3.106875419616699, grad_M_28=-3.454319477081299, grad_M_29=-2.5231235027313232, grad_M_3=1.2761918306350708, grad_M_30=2.191814661026001, grad_M_31=-5.462644100189209, grad_M_32=-5.522932052612305, grad_M_33=0.9577012062072754, grad_M_34=0.11772944033145905, grad_M_35=-5.550882816314697, grad_M_36=4.6640729904174805, grad_M_37=10.731704711914062, grad_M_38=-15.858097076416016, grad_M_39=1.7208471298217773, grad_M_4=-2.7806811332702637, grad_M_40=-2.6798512935638428, grad_M_41=-8.657978057861328, grad_M_42=6.570844650268555, grad_M_43=14.501526832580566, grad_M_44=-0.7536975145339966, grad_M_45=0.3949216604232788, grad_M_46=-9.662575721740723, grad_M_47=0.612733006477356, grad_M_48=5.8294525146484375, grad_M_49=-2.1301252841949463, grad_M_5=1.8556338548660278, grad_M_50=8.390154838562012, grad_M_51=7.767500400543213, grad_M_52=3.154741048812866, grad_M_53=-3.1608047485351562, grad_M_54=7.024104118347168, grad_M_55=-7.687121868133545, grad_M_56=0.32291945815086365, grad_M_57=11.693647384643555, grad_M_58=1.9413516521453857, grad_M_59=-2.13832426071167, grad_M_6=-5.325369834899902, grad_M_60=-5.38056755065918, grad_M_61=-3.6839609146118164, grad_M_62=-1.3379706144332886, grad_M_63=6.041138648986816, grad_M_7=-20.546916961669922, grad_M_8=1.745859980583191, grad_M_9=-3.7440028190612793, grad_sq_norm=5.679286, loss=0.447439, mem.available=1216746 ...
# INFO:absl:[200] M_0=-0.10064494609832764, M_1=-0.00023301491455640644, M_10=0.001607538782991469, M_11=-0.0021740873344242573, M_12=-0.001519214129075408, M_13=-0.002885517431423068, M_14=-0.0011890660971403122, M_15=0.001451892196200788, M_16=0.0013514099409803748, M_17=0.003202569205313921, M_18=-0.002034258795902133, M_19=-0.00021341624960768968, M_2=-0.000707338098436594, M_20=0.0009092931286431849, M_21=0.0016456109005957842, M_22=-0.0033003119751811028, M_23=0.0003126835508737713, M_24=1.1130200618936215e-05, M_25=7.636693771928549e-05, M_26=0.0026452834717929363, M_27=-9.618047442927491e-06, M_28=-0.0023886761628091335, M_29=-0.0021491418592631817, M_3=-0.0013080709613859653, M_30=0.0013143385294824839, M_31=0.0003472744720056653, M_32=-8.443609112873673e-05, M_33=0.0028657112270593643, M_34=0.0007070494466461241, M_35=-0.00271476898342371, M_36=-0.0005499870167113841, M_37=0.002010331954807043, M_38=0.00493946298956871, M_39=0.00024239116464741528, M_4=0.0004338491999078542, M_40=-0.0019123443635180593, M_41=0.002110298490151763, M_42=0.0007866451051086187, M_43=-0.00039183677290566266, M_44=0.002407748717814684, M_45=-0.0019802243914455175, M_46=0.0006793084321543574, M_47=-0.000661808589939028, M_48=-0.0005157378618605435, M_49=0.0012314501218497753, M_5=-0.0027808737941086292, M_50=-0.002135246293619275, M_51=-0.0014911983162164688, M_52=0.0026606277097016573, M_53=-0.003036526031792164, M_54=-0.0023196369875222445, M_55=0.0005429999437183142, M_56=-0.00504830339923501, M_57=-0.0010681303683668375, M_58=0.0006293835467658937, M_59=0.0018593065906316042, M_6=0.0008808237034827471, M_60=0.0012811506167054176, M_61=0.0012927543139085174, M_62=0.00013988286082167178, M_63=-0.0016727278707548976, M_7=0.0006471042870543897, M_8=0.0038836998865008354, M_9=-0.0003221036749891937, cost_fn_history_memory=21819, cpu.freq.current=3504, cpu.util.avg_percent_since_last=55.400000, disturbance_history_memory=640, disturbance_transform_state_memory=40, global_step=200, gpc_cost=0.4175238013267517, grad_M_0=-0.1143447756767273, grad_M_1=-1.4444741010665894, grad_M_10=6.5220770835876465, grad_M_11=3.77351713180542, grad_M_12=-6.146247386932373, grad_M_13=5.022344589233398, grad_M_14=-1.1931169033050537, grad_M_15=0.39629995822906494, grad_M_16=0.8526030778884888, grad_M_17=-1.8452935218811035, grad_M_18=3.3544552326202393, grad_M_19=1.010969877243042, grad_M_2=-3.8877742290496826, grad_M_20=3.075194835662842, grad_M_21=2.0268659591674805, grad_M_22=6.8512444496154785, grad_M_23=5.130313396453857, grad_M_24=-3.337839365005493, grad_M_25=7.749312877655029, grad_M_26=-3.5836448669433594, grad_M_27=-3.21090030670166, grad_M_28=-3.0397651195526123, grad_M_29=-12.450383186340332, grad_M_3=12.198978424072266, grad_M_30=9.8422269821167, grad_M_31=-6.471487045288086, grad_M_32=2.8218865394592285, grad_M_33=-2.839494228363037, grad_M_34=4.332219123840332, grad_M_35=-0.5521750450134277, grad_M_36=-3.5667362213134766, grad_M_37=-7.029881954193115, grad_M_38=2.682459592819214, grad_M_39=-1.3654167652130127, grad_M_4=2.6307404041290283, grad_M_40=10.493476867675781, grad_M_41=7.4314727783203125, grad_M_42=5.335090160369873, grad_M_43=-2.7034897804260254, grad_M_44=9.475814819335938, grad_M_45=-3.6360390186309814, grad_M_46=-6.773852348327637, grad_M_47=-9.672392845153809, grad_M_48=-4.849226474761963, grad_M_49=-14.986303329467773, grad_M_5=4.618143081665039, grad_M_50=-7.90277099609375, grad_M_51=8.372697830200195, grad_M_52=-13.7839994430542, grad_M_53=-2.5324907302856445, grad_M_54=9.591761589050293, grad_M_55=3.767747163772583, grad_M_56=-1.10480797290802, grad_M_57=0.7788900136947632, grad_M_58=15.160737037658691, grad_M_59=12.420768737792969, grad_M_6=-0.4169670343399048, grad_M_60=-17.75295639038086, grad_M_61=-16.289579391479492, grad_M_62=1.257031798362732, grad_M_63=5.727362632751465, grad_M_7=1.9926420450210571, grad_M_8=-10.244735717773438, grad_M_9=-14.193012237548828, grad_sq_norm=5.387664, loss=0.420857, mem.available=11985108992, me ...
# INFO:absl:Profiler Report
# :
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                  	|  Mean Duration (s)	|  Std Duration (s)	|  Num Calls      	|  Total Time (s) 	|  Percentage %   	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                   	|  -----          	|  -----          	|  245            	|  17.814         	|  100 %          	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Train                                                                                   	|  17.809         	|  0.0            	|  1              	|  17.809         	|  99.97          	|
# |  Update parameters                                                                       	|  0.056729       	|  0.092041       	|  200            	|  11.346         	|  63.69          	|
# |  Collecting step metrics                                                                 	|  0.14461        	|  0.046144       	|  42             	|  6.0737         	|  34.095         	|
# |  Initializing dataset for workload: mnist.                                  	|  0.074347       	|  0.0            	|  1              	|  0.074347       	|  0.41735        	|
# |  Initializing the model (for mnist) and also optimizer: MetaOpt	|  0.027885       	|  0.0            	|  1              	|  0.027885       	|  0.15653        	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 82781), started 0:05:30 ago. (Use '!kill 82781' to kill it.)
#       <iframe id="tensorboard-frame-a7d4322b0bafd0b9" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-a7d4322b0bafd0b9");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# # random tests

# %%
# import chex
# import numpy as np

# def compute(gpc_params: chex.Array, 
#                         disturbance_history: chex.Array) -> chex.Array:
#     ret = jnp.dot(disturbance_history.T, gpc_params)
#     return ret

# @jax.custom_jvp
# def compute2(gpc_params: chex.Array, 
#                 disturbance_history: chex.Array) -> chex.Array:
#     ret = disturbance_history.T @ gpc_params
#     return ret

# @compute2.defjvp
# def compute2_jvp(primals, tangents):
#     g, d = primals
#     g_dot, d_dot = tangents
#     primal_out = compute2(g, d)
#     tangent_out = d.T @ g_dot
#     return primal_out, tangent_out


# # @custom_jvp
# # def f(x, y):
# #   return x ** 2 * y

# # @f.defjvp
# # def f_jvp(primals, tangents):
# #   x, y = primals
# #   x_dot, y_dot = tangents
# #   primal_out = f(x, y)
# #   tangent_out = 2 * x * y * x_dot + x ** 2 * y_dot
# #   return primal_out, tangent_out

# def loss(p, d):
#     return jnp.linalg.norm(compute(p, d) + jax.random.normal(jax.random.PRNGKey(0), d.shape[1:]))
# def loss2(p, d):
#     return jnp.linalg.norm(compute2(p, d) + jax.random.normal(jax.random.PRNGKey(0), d.shape[1:]))

# gpc_params = jnp.array(np.random.randn(32,))
# disturbance_history = jnp.array(np.random.randn(32, 2048))

# print('losses')
# print(loss(gpc_params, disturbance_history))
# print(loss2(gpc_params, disturbance_history))

# print('grads')
# print(jax.grad(loss)(gpc_params, disturbance_history))
# print(jax.grad(loss2)(gpc_params, disturbance_history))
